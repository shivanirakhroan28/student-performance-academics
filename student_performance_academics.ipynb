# %% [markdown]
# #  Import  Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
df= pd.read_csv(r"C:\Users\shivani\Downloads\Student_performance_data _.csv")

# %%
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df.shape
# Out:
# (2392, 15)

# %%
df.isna().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %% [markdown]
# #  To check Statistical Summary

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
df.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
df['GradeClass'].nunique()
# Out:
# 5

# %%
for i in df.select_dtypes(include='int').columns:
    print(f"-------value_counts----")
    print(df[i].value_counts())
# Out:
# -------value_counts----
# StudentID
# 1001    1
# 2590    1
# 2592    1
# 2593    1
# 2594    1
#        ..
# 1798    1
# 1799    1
# 1800    1
# 1801    1
# 3392    1
# Name: count, Length: 2392, dtype: int64
# -------value_counts----
# Age
# 15    630
# 16    593
# 17    587
# 18    582
# Name: count, dtype: int64
# -------value_counts----
# Gender
# 1    1222
# 0    1170
# Name: count, dtype: int64
# -------value_counts----
# Ethnicity
# 0    1207
# 1     493
# 2     470
# 3     222
# Name: count, dtype: int64
# -------value_counts----
# ParentalEducation
# 2    934
# 1    728
# 3    367
# 0    243
# 4    120
# Name: count, dtype: int64
# -------value_counts----
# Absences
# 25    93
# 13    93
# 12    92
# 8     91
# 19    90
# 20    90
# 6     88
# 15    87
# 23    86
# 7     86
# 1     85
# 27    84
# 14    84
# 5     83
# 21    83
# 17    81
# 24    81
# 26    80
# 3     79
# 16    79
# 18    79
# 11    71
# 22    71
# 2     69
# 29    69
# 4     69
# 0     67
# 9     67
# ...

# %%
df.head(4)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0

# %%
df.drop(columns=['Volunteering','ParentalSupport','Ethnicity'],axis=1,inplace=True)

# %% [markdown]
# #  EDA

# %%
def box_plot(df):
    cols=df.columns
    
    
    fig,axes=plt.subplots(4,3,figsize=(15,7))
    axes=axes.flatten()
    for i,j in enumerate(cols):
        sns.boxplot(x=df[j],ax=axes[i])
        axes[i].set_title(f"{j}.skewess{df[j].skew().round(2)}")
    plt.tight_layout()
    plt.show()

# %%
box_plot(df)

# %%
df.hist(bins=50,figsize=(12,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.show()

# %%
df.head(4)
# Out:
#    StudentID  Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# 0       1001   17       1                  2        19.833723         7
# 1       1002   18       0                  1        15.408756         0
# 2       1003   15       0                  3         4.210570        26
# 3       1004   17       1                  3        10.028829        14
#
#    Tutoring  Extracurricular  Sports  Music       GPA  GradeClass
# 0         1                0       0      1  2.929196         2.0
# 1         0                0       0      0  3.042915         1.0
# 2         0                0       0      0  0.112602         4.0
# 3         0                1       0      0  2.054218         3.0

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# # Separating Feature and Target

# %%
x= df.drop('GradeClass',axis=1)
y= df['GradeClass']

# %%
#from sklearn.preprocessing import MinMaxScaler

# %%
#mn= MinMaxScaler()

# %%
#x= mn.fit_transform(x)

# %%
#x

# %% [markdown]
# # Splitting Data into training & testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,shuffle=True,random_state=42,stratify=y)

# %%
print('shape of x_train:', x_train.shape)
print('shape of x_test:', x_test.shape)
print('shape of y_train:', y_train.shape)
print('shape of y_test:', y_test.shape)
# Out:
# shape of x_train: (1913, 11)
# shape of x_test: (479, 11)
# shape of y_train: (1913,)
# shape of y_test: (479,)

# %% [markdown]
# # Implementing model-1: KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn= KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_train,y_train)
# Out:
# 0.7354939884997387

# %%
knn.score(x_test,y_test)
# Out:
# 0.5824634655532359

# %%
train_score=[]
test_score=[]

for i in range(1,16):
    knn= KNeighborsClassifier(n_neighbors=i,metric='euclidean')
    knn.fit(x_train,y_train)
    train_score.append(knn.score(x_train,y_train))
    test_score.append(knn.score(x_test,y_test))

# %%
train_score
# Out:
# [1.0,
#  0.8050182958703607,
#  0.778881338212232,
#  0.7475169890224778,
#  0.7354939884997387,
#  0.7208572922111867,
#  0.7077888133821223,
#  0.6952430737062206,
#  0.6884474647151072,
#  0.6753789858860428,
#  0.6644014636696288,
#  0.6591740721380032,
#  0.6502875065342394,
#  0.6387872451646628,
#  0.6272869837950863]

# %%
test_score
# Out:
# [0.5782881002087683,
#  0.5302713987473904,
#  0.5824634655532359,
#  0.5657620041753654,
#  0.5824634655532359,
#  0.5782881002087683,
#  0.5845511482254697,
#  0.5782881002087683,
#  0.5720250521920668,
#  0.5803757828810021,
#  0.5782881002087683,
#  0.5845511482254697,
#  0.5720250521920668,
#  0.5720250521920668,
#  0.569937369519833]

# %%
rg= list(range(1,16))
plt.figure(figsize=(12,8))
plt.plot(rg,train_score,label='Train_score')
plt.plot(rg,test_score,label='Test_score')
plt.legend()
plt.show()

# %%
knn= KNeighborsClassifier(n_neighbors=15,metric='euclidean')

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=15)

# %%
knn.score(x_train,y_train)
# Out:
# 0.6272869837950863

# %%
knn.score(x_test,y_test)
# Out:
# 0.569937369519833

# %%
knn= knn.predict(x_test)

# %%
result= pd.DataFrame(knn,columns=['KNN'])

# %%
result['Actual_data']= np.array(y_test)

# %%
result
# Out:
#      KNN  Actual_data
# 0    4.0          4.0
# 1    4.0          4.0
# 2    4.0          4.0
# 3    4.0          4.0
# 4    1.0          2.0
# ..   ...          ...
# 474  4.0          4.0
# 475  2.0          1.0
# 476  4.0          4.0
# 477  4.0          2.0
# 478  4.0          4.0
#
# [479 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(knn,y_test))
# Out:
# [[  0   4   1   1   2]
#  [  7  12   6   8   2]
#  [  5  16  21  13   5]
#  [  3   9   7  14   8]
#  [  6  13  43  47 226]]

# %%
print(classification_report(knn,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         8
#          1.0       0.22      0.34      0.27        35
#          2.0       0.27      0.35      0.30        60
#          3.0       0.17      0.34      0.23        41
#          4.0       0.93      0.67      0.78       335
#
#     accuracy                           0.57       479
#    macro avg       0.32      0.34      0.32       479
# weighted avg       0.71      0.57      0.62       479

# %% [markdown]
# # Implementing model-2: RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfr= RandomForestClassifier()

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfr.score(x_train,y_train)
# Out:
# 1.0

# %%
rfr.score(x_test,y_test)
# Out:
# 0.9227557411273486

# %%
rfr= rfr.predict(x_test)

# %%
result['RfC']= rfr

# %%
print(confusion_matrix(rfr,y_test))
# Out:
# [[ 11   0   0   0   2]
#  [  3  50   0   2   6]
#  [  3   1  74   3   1]
#  [  2   2   2  75   2]
#  [  2   1   2   3 232]]

# %%
print(classification_report(rfr,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.85      0.65        13
#          1.0       0.93      0.82      0.87        61
#          2.0       0.95      0.90      0.93        82
#          3.0       0.90      0.90      0.90        83
#          4.0       0.95      0.97      0.96       240
#
#     accuracy                           0.92       479
#    macro avg       0.85      0.89      0.86       479
# weighted avg       0.93      0.92      0.92       479

# %% [markdown]
# # Implementing model-3: GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb= GradientBoostingClassifier(loss='log_loss',
    learning_rate=0.8)

# %%
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.8)

# %%
gb.score(x_train,y_train)
# Out:
# 1.0

# %%
gb.score(x_test,y_test)
# Out:
# 0.918580375782881

# %%
gb= gb.predict(x_test)

# %%
result['Gb']=gb

# %%
print(confusion_matrix(gb,y_test))
# Out:
# [[ 11   1   3   1   4]
#  [  3  48   0   4   5]
#  [  2   2  73   1   0]
#  [  4   3   1  75   1]
#  [  1   0   1   2 233]]

# %%
print(classification_report(gb,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.55      0.54        20
#          1.0       0.89      0.80      0.84        60
#          2.0       0.94      0.94      0.94        78
#          3.0       0.90      0.89      0.90        84
#          4.0       0.96      0.98      0.97       237
#
#     accuracy                           0.92       479
#    macro avg       0.84      0.83      0.84       479
# weighted avg       0.92      0.92      0.92       479

# %% [markdown]
# # Implementing model-4: DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc= DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(x_train,y_train)
# Out:
# 1.0

# %%
dtc.score(x_test,y_test)
# Out:
# 0.9144050104384134

# %%
dtc= dtc.predict(x_test)

# %%
result['Dtc']= dtc

# %%
print(confusion_matrix(dtc,y_test))
# Out:
# [[ 11   2   0   2   3]
#  [  6  45   0   3   6]
#  [  2   1  74   1   2]
#  [  1   3   1  76   0]
#  [  1   3   3   1 232]]

# %%
print(classification_report(dtc,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.61      0.56        18
#          1.0       0.83      0.75      0.79        60
#          2.0       0.95      0.93      0.94        80
#          3.0       0.92      0.94      0.93        81
#          4.0       0.95      0.97      0.96       240
#
#     accuracy                           0.91       479
#    macro avg       0.84      0.84      0.84       479
# weighted avg       0.92      0.91      0.91       479

# %% [markdown]
# # Implementing  RandomForestClassifier , evaluating it based on Accuracy & Recall

# %%
rfr= RandomForestClassifier()

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rfr.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
grid= {
    'criterion':["gini", "entropy", "log_loss"],
    
    'max_depth': [50,100,150,200,250],
    'min_samples_leaf': list(range(1,10)),
    'min_samples_split': list(range(1,10))
}

# %%
rscv= RandomizedSearchCV(estimator=rfr,param_distributions=grid,cv=5)

# %%
rscv.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': [50, 100, 150, 200, 250],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5, 6,
#                                                              7, 8, 9],
#                                         'min_samples_split': [1, 2, 3, 4, 5, 6,
#                                                               7, 8, 9]})

# %%
rscv.best_estimator_
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=200, min_samples_leaf=6,
#                        min_samples_split=7)

# %%
rscv.best_score_
# Out:
# 0.9159144312156602

# %%
rscv.best_params_
# Out:
# {'min_samples_split': 7,
#  'min_samples_leaf': 6,
#  'max_depth': 200,
#  'criterion': 'log_loss'}

# %%
rfr= RandomForestClassifier(min_samples_split= 6,
 min_samples_leaf= 9,
 max_depth= 50,
 
 criterion= 'entropy')

# %%
rfr.fit(x,y)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=50, min_samples_leaf=9,
#                        min_samples_split=6)

# %%
rfr.score(x,y)
# Out:
# 0.9414715719063546

# %%
rfr= rfr.predict(x_test)

# %% [markdown]
# # Comparison of Predicted and Actual Values

# %%
result= pd.DataFrame(rfr,columns=['Prediction'])

# %%
result['ACtual_value']=np.array(y_test)

# %%
result
# Out:
#      Prediction  ACtual_value
# 0           4.0           4.0
# 1           4.0           4.0
# 2           4.0           4.0
# 3           4.0           4.0
# 4           2.0           2.0
# ..          ...           ...
# 474         4.0           4.0
# 475         1.0           1.0
# 476         4.0           4.0
# 477         2.0           2.0
# 478         4.0           4.0
#
# [479 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
acuracy= accuracy_score(result['Prediction'],result['ACtual_value'])

# %%
acuracy
# Out:
# 0.9352818371607515

# %%
print(classification_report(rfr,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.52      1.00      0.69        11
#          1.0       0.93      0.91      0.92        55
#          2.0       0.96      0.91      0.94        82
#          3.0       0.92      0.89      0.90        85
#          4.0       0.97      0.96      0.97       246
#
#     accuracy                           0.94       479
#    macro avg       0.86      0.94      0.88       479
# weighted avg       0.94      0.94      0.94       479

# %%
df.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'ParentalEducation', 'StudyTimeWeekly',
#        'Absences', 'Tutoring', 'Extracurricular', 'Sports', 'Music', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %% [markdown]
# # Deployed Student Performance Prediction System

# %%
StudentID = int(input('StudentID='))
Age = int(input('Age='))
Gender = int(input('Gender='))
ParentalEducation = int(input('ParentalEducation='))
StudyTimeWeekly = float(input('StudyTimeWeekly='))
Absences = int(input('Absences='))
Tutoring = int(input('Tutoring='))
Extracurricular = int(input('Extracurricular='))
Sports = int(input('Sports='))
Music = int(input('Music='))
GPA = float(input('GPA='))

# 1004	17	1	0	3	10.028829	14	0	3	1	0	0	0	2.054218	3.0
# Out:
# StudentID=1004
# Age=17
# Gender=1
# ParentalEducation=0
# StudyTimeWeekly=10.028
# Absences=14
# Tutoring=0
# Extracurricular=3
# Sports=1
# Music=0
# GPA=3.0

# %%
data=[[StudentID,Age,Gender,ParentalEducation,StudyTimeWeekly,Absences,Tutoring,Extracurricular,Sports,Music,GPA]]

# %%
data
# Out:
# [[1004, 17, 1, 0, 10.028, 14, 0, 3, 1, 0, 3.0]]

# %%
rfr= RandomForestClassifier(min_samples_split= 6,
 min_samples_leaf= 9,
 max_depth= 50,
 
 criterion= 'entropy')

# %%
rfr.fit(x,y)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=50, min_samples_leaf=9,
#                        min_samples_split=6)

# %%
rfr.score(x,y)
# Out:
# 0.93938127090301

# %%
prediction= rfr.predict(data)

# %%
prediction
# Out:
# array([2.])

# %% [markdown]
# # Prediction Outcome:

# %% [raw]
# Based on the input data regarding StudentID , including factors such as age, gender, parental education, study time per week, extracurricular activities, and GPA, the deployed RandomForestClassifier model has predicted the student's Grade Class to be 2.

# %% [markdown]
# # Recommendations:

# %% [raw]
# 1.Encourage Attendance: Regular attendance is crucial for better academic performance. Schools should identify and support students with high absences through intervention programs.
#
# 2.Boost Study Habits: Students with lower study times should be encouraged to adopt better study routines. Workshops on time management and personalized study plans can help.
#
# 3.Increase Tutoring and Parental Support: Access to tutoring and parental involvement are key to improving student outcomes. Schools should enhance these resources for students in need.
#
# 4.Balance Extracurriculars: Encourage students to participate in extracurricular activities, but ensure a healthy balance between academics and other pursuits.
#
# 5.Early Interventions: Focus on at-risk students (those with low GPAs and high absences) with targeted support, including academic assistance and mentoring.

# %% [markdown]
# # Conclusion:

# %% [raw]
# Academic performance, as reflected by GPA, is strongly influenced by factors such as study time, attendance, and support systems. By fostering better attendance, study habits, and offering additional support, schools can significantly improve student outcomes. Maintaining a balance between academics and extracurricular activities is essential for holistic development.
